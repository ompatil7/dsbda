# %% [markdown]
# Perform the following operations on iris dataset
# 1. List down the features and their types
# 2. Create a box plot and histogram for each feature in the dataset.
# 3. Compare distributions and identify outliers.

# %% [markdown]
# ## Loading the data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('IRIS.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## List down the features and their types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Create a box plot and histogram for each feature in the dataset

# %%
feature = 'sepal_length'


#boxplot
plt.figure(figsize=(6,4))
sns.boxplot(x='species', y=feature, data=df)
plt.title(f"Box plot for {feature}")
plt.show()

#histogram
plt.figure(figsize=(6,4))
sns.histplot(data=df, x=feature, kde=True)
plt.title(f"Histogram of {feature}")
plt.show()

#now u can do the same for all the ccolumns by changing the feature variable
# or 
# u can use this for loop
# Create box plots for each feature
# plt.figure(figsize=(12, 8))
# for i, column in enumerate(df.columns[:-1]):
#     plt.subplot(2, 2, i + 1)
#     sns.boxplot(x='species', y=column, data=df)
#     plt.title(column)

# plt.tight_layout()
# plt.show()

# # Create histograms for each feature
# plt.figure(figsize=(12, 8))
# for i, column in enumerate(df.columns[:-1]):
#     plt.subplot(2, 2, i + 1)
#     sns.histplot(data=df, x=column, kde=True)
#     plt.title(column)

# plt.tight_layout()
# plt.show()
# Out:
# E:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Compare distributions and identify outliers

# %%
# Choose a single feature (e.g., 'sepal_length')
feature = 'sepal_length'

# Create a box plot
plt.figure(figsize=(6, 4))
sns.boxplot(x='species', y=feature, data=df)
plt.title(f'Box plot of {feature}')
plt.show()

# Create a histogram
plt.figure(figsize=(6, 4))
sns.histplot(data=df, hue='species', x=feature)
plt.title(f'Histogram of {feature}')
plt.show()

# Identify outliers
Q1 = df[feature].quantile(0.25)
Q3 = df[feature].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df[feature] < lower_bound) | (df[feature] > upper_bound)]
print(f'Identified outliers:\n{outliers}')
# Out:
# E:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Identified outliers:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
sns.catplot(x='sepal_length', hue='species', kind='count', data=df)
